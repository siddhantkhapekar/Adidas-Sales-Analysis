# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Games\Adidas US Sales.csv")
df
# Out:
#      invoice_date  sales_id     customer  customer_id     region  \
# 0      01-01-2020       229  Foot Locker      1185732  Northeast
# 1      01-01-2020        85  Foot Locker      1185732  Northeast
# 2      01-01-2020      9059  Foot Locker      1185732  Northeast
# 3      01-01-2020      6493  Foot Locker      1185732  Northeast
# 4      01-01-2020      4883  Foot Locker      1185732  Northeast
# ...           ...       ...          ...          ...        ...
# 9632   31-12-2021      6412       Amazon      1185732  Northeast
# 9633   31-12-2021      9602  Foot Locker      1185732  Northeast
# 9634   31-12-2021      5711  Foot Locker      1185732  Northeast
# 9635   31-12-2021      3452       Amazon      1185732  Northeast
# 9636   31-12-2021      5972  Foot Locker      1185732  Northeast
#
#              state          city                product  price_per_unit  \
# 0         New York      New York  Men's Street Footwear            47.0
# ...

# %%
df.columns
# Out:
# Index(['invoice_date', 'sales_id', 'customer', 'customer_id', 'region',
#        'state', 'city', 'product', 'price_per_unit', 'units_sold',
#        'total_sales', 'monthly_sales', 'sales_method', 'gender'],
#       dtype='object')

# %%
df.head()
# Out:
#   invoice_date  sales_id     customer  customer_id     region         state  \
# 0   01-01-2020       229  Foot Locker      1185732  Northeast      New York
# 1   01-01-2020        85  Foot Locker      1185732  Northeast      New York
# 2   01-01-2020      9059  Foot Locker      1185732  Northeast  Pennsylvania
# 3   01-01-2020      6493  Foot Locker      1185732  Northeast      New York
# 4   01-01-2020      4883  Foot Locker      1185732  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear            47.0       336.0
# 1      New York  Men's Street Footwear            34.0       384.0
# 2  Philadelphia        Women's Apparel            75.0       275.0
# 3      New York  Men's Street Footwear            50.0      1200.0
# 4  Philadelphia        Women's Apparel            68.0        83.0
#
#    total_sales monthly_sales sales_method gender
# 0  15792.00000           963       Online   MALE
# ...

# %%
df.tail()
# Out:
#      invoice_date  sales_id     customer  customer_id     region  \
# 9632   31-12-2021      6412       Amazon      1185732  Northeast
# 9633   31-12-2021      9602  Foot Locker      1185732  Northeast
# 9634   31-12-2021      5711  Foot Locker      1185732  Northeast
# 9635   31-12-2021      3452       Amazon      1185732  Northeast
# 9636   31-12-2021      5972  Foot Locker      1185732  Northeast
#
#              state          city        product  price_per_unit  units_sold  \
# 9632         Maine      Portland  Men's Apparel            52.0        36.0
# 9633  Pennsylvania  Philadelphia  Men's Apparel            70.0       175.0
# 9634  Pennsylvania  Philadelphia  Men's Apparel            46.0        56.0
# 9635         Maine      Portland  Men's Apparel            55.0       125.0
# 9636  Pennsylvania  Philadelphia  Men's Apparel            63.0        47.0
#
#       total_sales monthly_sales sales_method gender
# 9632       1872.0            69       Online   MALE
# ...

# %%
df.shape
# Out:
# (9637, 14)

# %%
df.describe()
# Out:
#           sales_id   customer_id  price_per_unit   units_sold   total_sales
# count  9637.000000  9.637000e+03     9569.000000  9576.000000   9507.000000
# mean   4819.000000  1.173846e+06       45.153529   256.496275  12427.332050
# std    2782.106606  2.636304e+04       14.687746   213.809834  12699.750847
# min       1.000000  1.128299e+06        5.000000     6.000000    203.000000
# 25%    2410.000000  1.185732e+06       35.000000   106.000000   4067.500000
# 50%    4819.000000  1.185732e+06       45.000000   176.000000   7820.000000
# 75%    7228.000000  1.185732e+06       55.000000   349.250000  15750.000000
# max    9637.000000  1.197831e+06      110.000000  1275.000000  82500.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9637 entries, 0 to 9636
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_date    9637 non-null   object
#  1   sales_id        9637 non-null   int64
#  2   customer        9637 non-null   object
#  3   customer_id     9637 non-null   int64
#  4   region          9637 non-null   object
#  5   state           9637 non-null   object
#  6   city            9637 non-null   object
#  7   product         9637 non-null   object
#  8   price_per_unit  9569 non-null   float64
#  9   units_sold      9576 non-null   float64
#  10  total_sales     9507 non-null   float64
#  11  monthly_sales   9505 non-null   object
#  12  sales_method    9637 non-null   object
#  13  gender          9637 non-null   object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# invoice_date        0
# sales_id            0
# customer            0
# customer_id         0
# region              0
# state               0
# city                0
# product             0
# price_per_unit     68
# units_sold         61
# total_sales       130
# monthly_sales     132
# sales_method        0
# gender              0
# dtype: int64

# %%
df["price_per_unit"]=df["price_per_unit"].fillna(df["price_per_unit"].mean())

# %%
df["units_sold"]=df["units_sold"].fillna(df["units_sold"].mean())

# %%
df["total_sales"]=df["total_sales"].fillna(df["total_sales"].mean())

# %%
df['monthly_sales'] = pd.to_numeric(df['monthly_sales'], errors='coerce')
df["monthly_sales"]=df["monthly_sales"].fillna(df["monthly_sales"].mean())

# %%
df.isnull().sum()
# Out:
# invoice_date      0
# sales_id          0
# customer          0
# customer_id       0
# region            0
# state             0
# city              0
# product           0
# price_per_unit    0
# units_sold        0
# total_sales       0
# monthly_sales     0
# sales_method      0
# gender            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#      invoice_date  sales_id     customer  customer_id     region  \
# 0      01-01-2020       229  Foot Locker      1185732  Northeast
# 1      01-01-2020        85  Foot Locker      1185732  Northeast
# 2      01-01-2020      9059  Foot Locker      1185732  Northeast
# 3      01-01-2020      6493  Foot Locker      1185732  Northeast
# 4      01-01-2020      4883  Foot Locker      1185732  Northeast
# ...           ...       ...          ...          ...        ...
# 9632   31-12-2021      6412       Amazon      1185732  Northeast
# 9633   31-12-2021      9602  Foot Locker      1185732  Northeast
# 9634   31-12-2021      5711  Foot Locker      1185732  Northeast
# 9635   31-12-2021      3452       Amazon      1185732  Northeast
# 9636   31-12-2021      5972  Foot Locker      1185732  Northeast
#
#              state          city                product  price_per_unit  \
# 0         New York      New York  Men's Street Footwear            47.0
# ...

# %%
total_sales_per_customer = df.groupby('customer')['total_sales'].sum().reset_index()

plt.figure(figsize=(10, 6))
c=["r","k","y","b","g","c"]
plt.bar(total_sales_per_customer['customer'], total_sales_per_customer['total_sales'],color=c)
plt.xlabel('Customer')
plt.ylabel('Total Sales Amount')
plt.title('Total Sales per Customer')
plt.show()

# %%
df['invoice_date'] = pd.to_datetime(df['invoice_date'], format='%d-%m-%Y')
df.set_index('invoice_date', inplace=True)
df.sort_index(inplace=True)
monthly_sales = df['total_sales'].resample('M').sum()
monthly_sales_ma = monthly_sales.rolling(window=3).mean()


plt.figure(figsize=(12, 6))
plt.plot(monthly_sales, label='Monthly Sales', marker='o')
plt.plot(monthly_sales_ma, label='3-Month Moving Average', linestyle='--')
plt.title('Monthly Sales and 3-Month Moving Average')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.to_csv("C:\Games\DA Project\codnera_project_adidas_sales.csv")
